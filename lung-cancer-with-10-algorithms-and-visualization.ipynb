# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv('/kaggle/input/lung-cancer/survey lung cancer.csv')
data
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(data['LUNG_CANCER'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(data, x='SMOKING', y='LUNG_CANCER', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(data['GENDER'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(data, x='SMOKING', y='GENDER', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(data['LUNG_CANCER'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(data, x='AGE', y='LUNG_CANCER', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(data['LUNG_CANCER'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(data, x='AGE', y='LUNG_CANCER', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(data['GENDER'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(data, x='AGE', y='GENDER', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['LUNG_CANCER'].value_counts()
    for x_label, grp in data.groupby('GENDER')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('GENDER')
_ = plt.ylabel('LUNG_CANCER')

# %%
from matplotlib import pyplot as plt
data['ANXIETY'].plot(kind='line', figsize=(8, 4), title='ANXIETY')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
data['YELLOW_FINGERS'].plot(kind='line', figsize=(8, 4), title='YELLOW_FINGERS')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
data['SMOKING'].plot(kind='line', figsize=(8, 4), title='SMOKING')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
data['AGE'].plot(kind='line', figsize=(8, 4), title='AGE')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
data.plot(kind='scatter', x='ANXIETY', y='PEER_PRESSURE', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
data.plot(kind='scatter', x='YELLOW_FINGERS', y='ANXIETY', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
data.plot(kind='scatter', x='SMOKING', y='YELLOW_FINGERS', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
data.plot(kind='scatter', x='AGE', y='SMOKING', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
data.groupby('LUNG_CANCER').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
data.groupby('GENDER').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
data['ANXIETY'].plot(kind='hist', bins=20, title='ANXIETY')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
data['YELLOW_FINGERS'].plot(kind='hist', bins=20, title='YELLOW_FINGERS')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
data['SMOKING'].plot(kind='hist', bins=20, title='SMOKING')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
data['AGE'].plot(kind='hist', bins=20, title='AGE')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
data.describe()
# Out:
#               AGE     SMOKING  YELLOW_FINGERS     ANXIETY  PEER_PRESSURE  \
# count  309.000000  309.000000      309.000000  309.000000     309.000000
# mean    62.673139    1.563107        1.569579    1.498382       1.501618
# std      8.210301    0.496806        0.495938    0.500808       0.500808
# min     21.000000    1.000000        1.000000    1.000000       1.000000
# 25%     57.000000    1.000000        1.000000    1.000000       1.000000
# 50%     62.000000    2.000000        2.000000    1.000000       2.000000
# 75%     69.000000    2.000000        2.000000    2.000000       2.000000
# max     87.000000    2.000000        2.000000    2.000000       2.000000
#
#        CHRONIC DISEASE    FATIGUE     ALLERGY     WHEEZING  ALCOHOL CONSUMING  \
# count       309.000000  309.000000  309.000000  309.000000         309.000000
# mean          1.504854    1.673139    1.556634    1.556634           1.556634
# ...

# %%
data.isnull().sum()
# Out:
# GENDER                   0
# AGE                      0
# SMOKING                  0
# YELLOW_FINGERS           0
# ANXIETY                  0
# PEER_PRESSURE            0
# CHRONIC DISEASE          0
# FATIGUE                  0
# ALLERGY                  0
# WHEEZING                 0
# ALCOHOL CONSUMING        0
# COUGHING                 0
# SHORTNESS OF BREATH      0
# SWALLOWING DIFFICULTY    0
# CHEST PAIN               0
# LUNG_CANCER              0
# dtype: int64

# %%
y=data['LUNG_CANCER']
df=data.drop(['LUNG_CANCER'],axis=1)

# %%
y.value_counts()
# Out:
# LUNG_CANCER
# YES    270
# NO      39
# Name: count, dtype: int64

# %%
df=pd.get_dummies(df)
df['GENDER_F'] = df['GENDER_F'].astype(int)
df['GENDER_M'] = df['GENDER_M'].astype(int)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_iris
import pandas as pd



rf = RandomForestClassifier(n_estimators=100)
rf.fit(df, y)

feature_importance = rf.feature_importances_

features = df.columns.tolist()
importance_df = pd.DataFrame({
    'Feature': features,
    'Importance': feature_importance
})

importance_df = importance_df.sort_values(by='Importance', ascending=False)
print(importance_df)
# Out:
#                   Feature  Importance
# 0                     AGE    0.220171
# 7                ALLERGY     0.095987
# 2          YELLOW_FINGERS    0.082076
# 4           PEER_PRESSURE    0.071768
# 9       ALCOHOL CONSUMING    0.071605
# 12  SWALLOWING DIFFICULTY    0.060979
# 6                FATIGUE     0.057087
# 5         CHRONIC DISEASE    0.053552
# 3                 ANXIETY    0.046176
# 8                WHEEZING    0.044739
# 10               COUGHING    0.043567
# 11    SHORTNESS OF BREATH    0.040850
# 13             CHEST PAIN    0.036065
# 1                 SMOKING    0.028088
# 15               GENDER_M    0.026019
# 14               GENDER_F    0.021272

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)
df, y = smote.fit_resample(df, y)

# %%
from sklearn.preprocessing import StandardScaler,LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)
sc = StandardScaler()
df = sc.fit_transform(df)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df, y, test_size=0.2, random_state=42, stratify=y, shuffle=True)

# %%
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, confusion_matrix
classifiers = {
    "SVM": SVC(),
    "Random Forest": RandomForestClassifier(),
    "Gradient Boosting": GradientBoostingClassifier(),
    "AdaBoost": AdaBoostClassifier(),
    "KNN": KNeighborsClassifier(),
    "Logistic Regression": LogisticRegression(),
    "Decision Tree": DecisionTreeClassifier(),
    "Naive Bayes": GaussianNB(),
    "LDA": LinearDiscriminantAnalysis(),
    "MLP": MLPClassifier()
}

for name, clf in classifiers.items():
    clf.fit(x_train, y_train)
    predictions = clf.predict(x_test)

    print(f"\n{name} Classifier Report")
    print(classification_report(y_test, predictions))
    print(confusion_matrix(y_test, predictions))
# Out:
# SVM Classifier Report
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91        54
#            1       0.91      0.91      0.91        54
#
#     accuracy                           0.91       108
#    macro avg       0.91      0.91      0.91       108
# weighted avg       0.91      0.91      0.91       108
#
# [[49  5]
#  [ 5 49]]
#
# Random Forest Classifier Report
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94        54
#            1       0.98      0.89      0.93        54
#
#     accuracy                           0.94       108
#    macro avg       0.94      0.94      0.94       108
# weighted avg       0.94      0.94      0.94       108
#
# [[53  1]
#  [ 6 48]]
#
# Gradient Boosting Classifier Report
#               precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93        54
#            1       0.96      0.89      0.92        54
# ...
